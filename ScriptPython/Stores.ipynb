# %% [markdown]
# ### Génération des données pour store

# %%
# importation de package necessaire
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import bcrypt
import random
import string
from unidecode import unidecode
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Constitution de la liste des magasins

# %%
# Region : 2Dakar, 1Thiès, 1Kaolack, 1Ziguinchor
lst_store = [
    {"Store_ID" : "Store001", 
     "Store_name" : "Beauty Treasure - Main Depot", 
     "Store_region" : "Dakar", 
     "Store_department" : "Dakar", 
     "Store_district" : "Mermoz Sacre Coeur", 
     "Store_phone_number" : "+221778596231", 
     "Creation_date" : "2022-02-18",  
     "Store_status" : "activated"},
    {"Store_ID" : "Store002", 
     "Store_name" : "Beauty Treasure - Radiance Reservoir", 
     "Store_region" : "Dakar", 
     "Store_department" : "Dakar", 
     "Store_district" : "Ngor", 
     "Store_phone_number" : "+221771562320", 
     "Creation_date" : "2022-02-18",  
     "Store_status" : "activated"},
    {"Store_ID" : "Store003", 
     "Store_name" : "Beauty Treasure - Luxury Chest", 
     "Store_region" : "Kaolack", 
     "Store_department" : "Kaolack", 
     "Store_district" : "Keur Soce", 
     "Store_phone_number" : "+221774698523", 
     "Creation_date" : "2022-02-18", 
     "Store_status" : "activated"},
    {"Store_ID" : "Store004", 
     "Store_name" : "Beauty Treasure - Seduction Sanctuary", 
     "Store_region" : "Thiès", 
     "Store_department" : "Thiès", 
     "Store_district" : "Keur Moussa", 
     "Store_phone_number" : "+221774588662", 
     "Creation_date" : "2022-02-18",  
     "Store_status" : "activated"},
    {"Store_ID" : "Store005", 
     "Store_name" : "Beauty Treasure - Glow Wardrobe", 
     "Store_region" : "Ziguinchor", 
     "Store_department" : "Ziguinchor", 
     "Store_district" : "Boutoupa Camaracound", 
     "Store_phone_number" : "+221774588662", 
     "Creation_date" : "2022-02-18", 
     "Store_status" : "activated"}
]
# création du dataframe
lst_columns = ["Store_ID", "Store_name", "Store_region", "Store_department", "Store_district", "Store_phone_number", "Creation_date", "Store_status"]
df_Stores = pd.DataFrame(columns=lst_columns)
for s in lst_store:
    df_Stores = df_Stores.append(s, ignore_index=True)

# enregistrement dans un fichier csv
store_csv = df_Stores.to_csv('dataset\stores.csv', encoding='utf-8-sig', index=False)

# %%
df_Stores
# Out:
#    Store_ID                             Store_name Store_region  \
# 0  Store001           Beauty Treasure - Main Depot        Dakar
# 1  Store002   Beauty Treasure - Radiance Reservoir        Dakar
# 2  Store003         Beauty Treasure - Luxury Chest      Kaolack
# 3  Store004  Beauty Treasure - Seduction Sanctuary        Thiès
# 4  Store005        Beauty Treasure - Glow Wardrobe   Ziguinchor
#
#   Store_department        Store_district Store_phone_number Creation_date  \
# 0            Dakar    Mermoz Sacre Coeur      +221778596231    2022-02-18
# 1            Dakar                  Ngor      +221771562320    2022-02-18
# 2          Kaolack             Keur Soce      +221774698523    2022-02-18
# 3            Thiès           Keur Moussa      +221774588662    2022-02-18
# 4       Ziguinchor  Boutoupa Camaracound      +221774588662    2022-02-18
#
#   Store_status
# 0    activated
# 1    activated
# 2    activated
# 3    activated
# 4    activated
