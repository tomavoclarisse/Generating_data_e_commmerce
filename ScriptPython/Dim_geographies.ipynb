# %% [markdown]
# ## Création des données de la table Dim_Geographies
# ### Url de provenances des infos ci dessous : https://www.au-senegal.com/les-regions-du-senegal,3605.html?lang=fr

# %%
# importation de package necessaire
import pandas as pd
import numpy as np
from datetime import datetime
import warnings 
warnings.filterwarnings("ignore")

lst_region = ["Dakar", "Diourbel", "Fatick", "Kaolack", "Kolda", "Louga", "Matam", "Saint-Louis", "Tambacounda", "Thiès", "Ziguinchor", "Sédhiou", "Kaffrine", "Kédougou"]
# création d'un dictionnaire dont les clés sont les régions et les valeurs sont les départements
department_region = {
    "Dakar" : ["Dakar", "Guédiawaye", "Pikine", "Rufisque"],
    "Diourbel" : ["BAMBEY", "DIOURBEL", "MBACKE"],
    "Fatick" : ["FATICK", "FOUNDIOUGNE", "GOSSAS"],
    "Kaolack" : ["GUINGUINEO", "KAOLACK", "NIORO DU RIP"]
}
department_district =  {"Dakar" : ["GUEULE TAPEE FASS COLOBANE", "FANN POINT E AMITIE", "GOREE", "MEDINA", "Plateau", "CAMBERENE" , "DIEUPPEUL DERKLE", "BISCUITERIE" , "HLM", "HANN BEL AIR", "Grand Dakar", "SICAP LIBERTE", "YOFF", "Mermoz Sacre coeur", "NGOR", "Ouakam", "Grand YOFF", "Parcelles Assainies", "Patte d'oie"],
 "Guédiawaye" : ["GOLF SUD", "MEDINA GOUNASS", "NDIAREME", "SAM NOTAIRE", "WAKHINANE NIMZAT"],
 "Pikine" : ["DALIFORT", "DJIDA THIAROYE KAO", "GUINAW RAIL NORD", "GUINAW RAIL SUD", "Pikine EST", "Pikine NORD", "Pikine OUEST", "KEUR MASSAR", "MALIKA", "YEUMBEUL NORD", "YEUMBEUL SUD", "MBAO", "DIAMAGUENE SICAP MBAO", "THIAROYE GARE", "THIAROYE SUR MER", "TIVAVOUANE DIAKSAO"],
 "Rufisque" : ["RUFISQUE EST", "RUFISQUE NORD", "RUFISQUE OUEST", "BAMBYLOR", "TIVAOUANE PEULH - NIAGA", "YENE", "BARGNY", "DIAMNIADIO", "JAXAAY-PLLES-NIAKOUL RAB", "SANGALKAM", "SEBIKOTANE", "SENDOU"],
 "BAMBEY" : ["BABA GARAGE", "DANGALMA", "DINGUIRAYE", "GAWANE", "KEUR SAMBA KANE", "LAMBAYE", "NDONDOL", "NGOGOM", "NGOYE", "REFANE", "THIAKHAR"],
 "DIOURBEL" : ["DANKH SENE", "GADE ESCALE", "KEUR NGALGOU", "NDINDY", "NDOULO", "NGOHE", "PATTAR", "TAIBA MOUTOUPHA", "TOCKY GARE", "TOURE MBONDE"],
 "MBACKE" : ["DALLA NGABOU", "DANDEYE GOUYGUI", "DAROU NAHIM", "DAROU SALAM TYP", "KAEL", "MADINA", "MISSIRAH", "NDIOUMANE", "NGHAYE", "SADIO", "TAIBA THIEKENE", "TAIF", "TOUBA FALL", "TOUBA MBOUL", "TOUBA MOSQUEE"],
 "FATICK" : ["DIAOULE", "DIARRERE", "DIOUROUP", "DJILASS", "FIMELA", "LOUL SESSENE", "MBELLACADIAO", "NDIOB", "NGAYOKHEME", "NIAKHAR", "PALMARIN FACAO", "PATAR", "TATTAGUINE", "THIARE NDIALGUI"],
 "FOUNDIOUGNE" : ["BASSOUL", "DIAGANE BARKA", "DIONEWAR", "DIOSSONG", "DJILOR", "DJIRNDA", "KEUR SALOUM DIANE", "KEUR SAMBA GUEYE", "MBAM", "NIASSENE", "NIORO ALASSANE TALL", "TOUBACOUTA"],
 "GOSSAS" : ["COLOBANE", "MBAR", "NDIENE LAGANE", "OUADIOUR", "PATAR LIA"] }

df_geography = pd.DataFrame(columns=['Geo_Key', 'Country', 'Region', 'Department', 'District', 'Creation_date'])
lst_geographies = []
id=1
for r in lst_region : 
    department_current = department_region[r] 
    for d in department_current:
        district_current = department_district[d]
        for dist in district_current:
            dic_current = {}
            dic_current["Geo_Key"] = id
            dic_current["Country"] = "Sénégal".title()
            dic_current["Region"] = r.title()
            dic_current["Department"] = d.title()
            dic_current["District"] = dist.title()
            dic_current["Creation_date"] = datetime.strptime("2022-03-01", '%Y-%m-%d').date()
            id=id+1
            lst_geographies.append(dic_current)
            
            
for geography in lst_geographies:
    df_geography = df_geography.append(geography, ignore_index=True)

# %%
# création de la liste des regions
# region
lst_region = ["Dakar", "Diourbel", "Fatick", "Kaolack", "Kolda", "Louga", "Matam", "Saint-Louis", "Tambacounda", "Thiès", "Ziguinchor", "Sédhiou", "Kaffrine", "Kédougou"]
# création d'un dictionnaire dont les clés sont les régions et les valeurs sont les départements
department_region = {
    "Dakar" : ["Dakar", "Guédiawaye", "Pikine", "Rufisque"],
    "Diourbel" : ["BAMBEY", "DIOURBEL", "MBACKE"],
    "Fatick" : ["FATICK", "FOUNDIOUGNE", "GOSSAS"],
    "Kaolack" : ["GUINGUINEO", "KAOLACK", "NIORO DU RIP"],
    "Kolda" : ["KOLDA", "MEDINA YORO FOULAH", "VELINGARA"],
    "Louga" : ["KEBEMER", "LINGUERE", "LOUGA"],
    "Matam" : ["KANEL", "MATAM", "RANEROU FERLO"],
    "Saint-Louis" : ["DAGANA", "PODOR", "SAINT-LOUIS"],
    "Tambacounda" : ["BAKEL", "GOUDIRY", "KOUMPENTOUM", "TAMBACOUNDA"],
    "Thiès" : ["MBOUR", "THIÈS", "TIVAOUANE"],
    "Ziguinchor" : ["BIGNONA", "OUSSOUYE", "ZIGUINCHOR"],
    "Sédhiou" : ["BOUNKILING", "GOUDOMP", "SÉDHIOU"],
    "Kaffrine" : ["BIRKILANE", "KAFFRINE", "KOUNGHEUL", "MALEM HODAR"],
    "Kédougou" : ["KEDOUGOU", "SALEMATA", "SARAYA"]
}
# création d'un dictionnaire dont les clés sont les départements et les valeurs sont les communautés rurales d'un département ou les arrondissement d'un département
department_district =  {"Dakar" : ["GUEULE TAPEE FASS COLOBANE", "FANN POINT E AMITIE", "GOREE", "MEDINA", "Plateau", "CAMBERENE" , "DIEUPPEUL DERKLE", "BISCUITERIE" , "HLM", "HANN BEL AIR", "Grand Dakar", "SICAP LIBERTE", "YOFF", "Mermoz Sacre coeur", "NGOR", "Ouakam", "Grand YOFF", "Parcelles Assainies", "Patte d'oie"],
 "Guédiawaye" : ["GOLF SUD", "MEDINA GOUNASS", "NDIAREME", "SAM NOTAIRE", "WAKHINANE NIMZAT"],
 "Pikine" : ["DALIFORT", "DJIDA THIAROYE KAO", "GUINAW RAIL NORD", "GUINAW RAIL SUD", "Pikine EST", "Pikine NORD", "Pikine OUEST", "KEUR MASSAR", "MALIKA", "YEUMBEUL NORD", "YEUMBEUL SUD", "MBAO", "DIAMAGUENE SICAP MBAO", "THIAROYE GARE", "THIAROYE SUR MER", "TIVAVOUANE DIAKSAO"],
 "Rufisque" : ["RUFISQUE EST", "RUFISQUE NORD", "RUFISQUE OUEST", "BAMBYLOR", "TIVAOUANE PEULH - NIAGA", "YENE", "BARGNY", "DIAMNIADIO", "JAXAAY-PLLES-NIAKOUL RAB", "SANGALKAM", "SEBIKOTANE", "SENDOU"],
 "BAMBEY" : ["BABA GARAGE", "DANGALMA", "DINGUIRAYE", "GAWANE", "KEUR SAMBA KANE", "LAMBAYE", "NDONDOL", "NGOGOM", "NGOYE", "REFANE", "THIAKHAR"],
 "DIOURBEL" : ["DANKH SENE", "GADE ESCALE", "KEUR NGALGOU", "NDINDY", "NDOULO", "NGOHE", "PATTAR", "TAIBA MOUTOUPHA", "TOCKY GARE", "TOURE MBONDE"],
 "MBACKE" : ["DALLA NGABOU", "DANDEYE GOUYGUI", "DAROU NAHIM", "DAROU SALAM TYP", "KAEL", "MADINA", "MISSIRAH", "NDIOUMANE", "NGHAYE", "SADIO", "TAIBA THIEKENE", "TAIF", "TOUBA FALL", "TOUBA MBOUL", "TOUBA MOSQUEE"],
 "FATICK" : ["DIAOULE", "DIARRERE", "DIOUROUP", "DJILASS", "FIMELA", "LOUL SESSENE", "MBELLACADIAO", "NDIOB", "NGAYOKHEME", "NIAKHAR", "PALMARIN FACAO", "PATAR", "TATTAGUINE", "THIARE NDIALGUI"],
 "FOUNDIOUGNE" : ["BASSOUL", "DIAGANE BARKA", "DIONEWAR", "DIOSSONG", "DJILOR", "DJIRNDA", "KEUR SALOUM DIANE", "KEUR SAMBA GUEYE", "MBAM", "NIASSENE", "NIORO ALASSANE TALL", "TOUBACOUTA"],
 "GOSSAS" : ["COLOBANE", "MBAR", "NDIENE LAGANE", "OUADIOUR", "PATAR LIA"],
 "GUINGUINEO" : ["DARA MBOSS", "KHELCOM BIRAME", "MBADAKHOUNE", "NDIAGO", "NGAGNICK", "NGATHIE NAOUDE", "NGELLOU", "OUROUR", "PANAL WOLOF"],
 "KAOLACK" :  ["DYA", "KEUR BAKA", "KEUR SOCE", "LATMINGUE", "NDIAFFATE", "NDIEBEL", "NDIEDIENG", "THIARE", "THIOMBY"],
 "NIORO DU RIP" : ["DABALY", "DAROU SALAM", "GAINTE KAYE", "KAYEMOR", "KEUR MABA DIAKHOU", "KEUR MADONGO", "MEDINA SABAKH", "NDRAME ESCALE", "NGAYENE", "PAOSKOTO", "POROKHANE", "TAIBA NIASSENE", "WACK NGOUNA"],
 "KOLDA" : ["BAGADAJI", "COUMBACARA", "DIALAMBERE", "DIOULACOLON", "GUIRO YERO BOCAR", "MAMPATIM", "MEDINA CHERIF", "MEDINA EL HADJI", "SARE BIDJI", "TANKANTO ESCALE", "THIETTY"],
 "MEDINA YORO FOULAH" : ["BADION", "BIGNARABE", "BOUROUCO", "FAFACOUROU", "KEREWANE", "KOULINTO", "NDORNA", "NIAMING"],
 "VELINGARA" : ["BONCONTO", "KANDIA", "KANDIAYE", "LINKERING", "MEDINA GOUNASSE", "NEMATABA", "OUASSADOU", "PAKOUR", "PAROUMBA", "SARE COLI SALLE", "SINTHIANG", "KOUNDARA"],
 "KEBEMER" : ["BANDEGNE OUOLOF", "DAROU MARNANE", "DAROU MOUSTI", "DIOKOUL NDIAWRIGNE", "KAB GAYE", "KANENE NDIOB", "LORO", "MBACKE CAJOR", "MBADIANE", "NDANDE", "NDOYENE", "NGOURANE OUOLOF", "SAGATA GUETH", "SAM YABAL", "THIEP", "THIOLOM FALL", "TOUBA MERINA"],
 "LINGUERE" : ["AFFE DJOLOF", "BARKEDJI", "BOULAL", "DEALY", "DODJI", "GASSANE", "KAMBE", "LABGAR", "MBOULA", "OUARKHOKH", "SAGATTA DJOLOF", "TESSEKERE FORAGE", "THIAMENE PASSE", "THIARGNY", "THIEL", "YANG YANG"],
 "LOUGA" : ["GANDE", "GUET ARDO", "KELLE GUEYE", "KEUR MOMAR SARR", "KOKI", "LEONA", "MBEDIENE", "NGUER MALAL", "NGUEUNE SARR", "NGUIDILE", "NIOMRE", "PETE OUARACK", "SAKAL", "SYER", "THIAMENE CAYOR"],
 "KANEL" : ["AOURE", "BOKILADJI", "NDENDORY", "ORKADIERE", "WOURO SIDY"],
 "MATAM" : ["BOKIDIAVE", "DABIA", "DES AGNAM (AGNAM CIVOL)", "NABADJI CIVOL", "OGO", "OREFONDE"],
 "RANEROU FERLO" : ["LOUGRE THIOLY", "OUDALAYE", "VELINGARA"],
 "DAGANA" : ["BOKHOL", "DIAMA", "GNITH", "MBANE", "RONKH"],
 "PODOR" : ["BOKE DIALLOUBE", "DODEL", "DOUMGA LAO", "FANAYE", "GAMADJI SARE", "GUEDE VILLAGE", "MADINA NDIATHBE", "MBOLO BIRANE", "MERI", "NDIAYENE PEINDAO"],
 "SAINT-LOUIS" : ["FASS NGOM", "GANDON", "NDIEBENE GANDIOLE"],
 "BAKEL" : ["BALLOU", "BELE", "GABOU", "GATHIARI", "MADINA FOULBE", "MOUDERI", "SADATOU", "SINTHIOU FISSA", "TOUMBOURA"],
 "GOUDIRY" : ["BALA", "BANI ISRAEL", "BOUTOUCOUFARA", "BOYNGUEL BAMBA", "DIANKE MAKHA", "DOUGUE", "GOUMBAYEL", "KOAR", "KOMOTI", "KOULOR", "KOUSSAN", "SINTHIOU BOCAR ALY", "SINTHIOU MAMADOU BOUBOU"],
 "KOUMPENTOUM" : ["BAMBA THIALENE", "KAHENE", "KOUTHIA GAYDI", "KOUTHIABA WOLOF", "MERETO", "NDAM", "PASS KOTO", "PAYAR"],
 "TAMBACOUNDA" : ["DIALOKOTO", "KOUSSANAR", "MAKACOLIBANTANG", "NDOGA BABACAR", "NETTEBOULOU", "NIANI TOUCOULEUR", "SINTHIOU MALEME"],
 "MBOUR" : ["DIASS", "FISSEL", "MALICOUNDA", "NDIAGANIAO", "NGUENIENE", "SANDIARA", "SESSENE", "SINDIA"],
 "THIÈS" : ["DIENDER GUEDJI", "FANDENE", "KEUR MOUSSA", "NDIEYENE SIRAKH", "NGOUNDIANE", "NOTTO", "TASSETTE", "THIENABA", "TOUBA TOUL"],
 "TIVAOUANE" : ["CHERIF LO", "DAROU KHOUDOSS", "KOUL", "MBAYENE", "MEOUANE", "MERINA DAKHAR", "MONT ROLLAND", "NGANDIOUF", "NIAKHENE", "NOTTO GOUYE DIAMA", "PAMBAL", "PEKESSE", "PIRE GOUREYE", "TAIBA NDIAYE", "THILMAKHA"],
 "BIGNONA" : ["BALINGORE", "COUBALAN", "DIEGOUNE", "DJIBIDIONE", "DJINAKI", "KAFOUNTINE", "KARTIACK", "KATABA 1", "MANGAGOULACK", "MLOMP", "NIAMONE", "OULAMPANE", "OUONCK", "SINDIAN", "SUEL", "TENGHORI"],
 "OUSSOUYE" : ["DIEMBERING", "OUKOUT", "SANTHIABA MANJAQUE"],
 "ZIGUINCHOR" : ["ADEANE", "BOUTOUPA CAMARACOUND", "ENAMPOR", "NIAGUIS", "NIASSIA"],
 "BOUNKILING" : ["BOGHAL", "BONA", "DIACOUNDA", "DIAMBATY", "DIAROUME", "DJINANY", "FAOUNE", "INOR", "KANDION MANGANA", "NDIAMALATHIEL", "TANKON"],
 "GOUDOMP" : ["BAGHERE", "DIOUDOUBOU", "DJIBANAR", "KAOUR", "KARANTABA", "KOLIBANTANG", "MANGAROUNGOU SANTO", "NIAGHA", "SIMBANDI BALANTE", "SIMBANDI BRASSOU", "YARANG BALANTE"],
 "SÉDHIOU" : ["BAMBALI", "BEMET BIDJINI", "DIANNAH BA", "DIENDE", "DJIBABOUYA", "DJIREDJI", "KOUSSY", "OUDOUCAR", "SAKAR", "SAME KANTA PEULH", "SANSAMBA"],
 "BIRKILANE" : ["DIAMAL", "KEUR MBOUCKI", "MABO", "MBEULEUP", "NDIOGNICK", "SEGRE GATTA", "TOUBA MBELLA"],
 "KAFFRINE" : ["BOULEL", "DIAMAGADIO", "DIOKOUL MBELBOUCK", "GNIBY", "KAHI", "KATHIOTE", "MEDINATOUL SALAM 2"],
 "KOUNGHEUL" : ["FASS THIEKENE", "IDA MOURIDE", "LOUR ESCALE", "MAKA YOP", "MISSIRAH WADENE", "NGAINTHE PATE", "RIBOT ESCALE", "SALY ESCALE"],
 "MALEM HODAR" : ["DAROU MINAM", "DJANKE SOUF", "KHELCOM", "NDIOBENE SAMBA LAMO", "NDIOUM NGAINTHE", "SAGNA"],
 "KEDOUGOU" : ["BANDAFASSI", "DIMBOLI", "DINDEFELO", "FONGOLIMBI", "NINEFECHA", "TOMBORONKOTO"],
 "SALEMATA" : ["DAKATELY", "DAR SALAM", "ETHIOLO", "KEVOYE", "OUBADJI"],
 "SARAYA" : ["BEMBOU", "KHOSSANTO", "MEDINA BAFFE", "MISSIRAH SIRIMANA", "SABODOLA"]
}

# %%
# création d'un dataframe pandas
df_geography = pd.DataFrame(columns=['Geo_Key', 'Country', 'Region', 'Department', 'District', 'Creation_date'])
lst_geographies = []
id=1
for r in lst_region : 
    department_current = department_region[r] 
    for d in department_current:
        district_current = department_district[d]
        for dist in district_current:
            dic_current = {}
            dic_current["Geo_Key"] = id
            dic_current["Country"] = "Sénégal".title()
            dic_current["Region"] = r.title()
            dic_current["Department"] = d.title()
            dic_current["District"] = dist.title()
            dic_current["Creation_date"] = datetime.strptime("2022-03-01", '%Y-%m-%d').date()
            id=id+1
            lst_geographies.append(dic_current)
            
            
for geography in lst_geographies:
    df_geography = df_geography.append(geography, ignore_index=True)

# %%
# conversion du dataframe df_geography en fichier csv
geographies_csv = df_geography.to_csv('dataset\geographies.csv', encoding='utf-8-sig', index=False)
# Affichage du DataFrame
df_geography
# Out:
#     Geo_Key  Country    Region Department                    District  \
# 0         1  Sénégal     Dakar      Dakar  Gueule Tapee Fass Colobane
# 1         2  Sénégal     Dakar      Dakar         Fann Point E Amitie
# 2         3  Sénégal     Dakar      Dakar                       Goree
# 3         4  Sénégal     Dakar      Dakar                      Medina
# 4         5  Sénégal     Dakar      Dakar                     Plateau
# ..      ...      ...       ...        ...                         ...
# 426     427  Sénégal  Kédougou     Saraya                      Bembou
# 427     428  Sénégal  Kédougou     Saraya                   Khossanto
# 428     429  Sénégal  Kédougou     Saraya                Medina Baffe
# 429     430  Sénégal  Kédougou     Saraya           Missirah Sirimana
# 430     431  Sénégal  Kédougou     Saraya                    Sabodola
#
#     Creation_date
# 0      2022-03-01
# 1      2022-03-01
# 2      2022-03-01
# 3      2022-03-01
# 4      2022-03-01
# ...

# %%
delivery_free = [{"District" : "", "Delivery_fee_standard" : "", "Delivery_fee_express" : "", "Delivery_status" : "activated"}]
